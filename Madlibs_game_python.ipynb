# %% [markdown]
# # FUN MADLIBS GAME USING PYTHON.

# %% [markdown]
# #### Introduction.

# %%
print()
print('HAVE FUN!!! PLAYING MADLIBS.')
print()
print('**Pro Tip:** The sillier and more random the words, the funnier the story becomes!')
print()
# Out:
# HAVE FUN!!! PLAYING MADLIBS.
#
# **Pro Tip:** The sillier and more random the words, the funnier the story becomes!

# %% [markdown]
# #### Establishing Rules

# %%
print('''RULES: \n
 1.	Ask your friend to input the words.\n
 2. Ask for a word that matches each part of speech (e.g., "Give me an adjective for blank 1")\n
 3. Input the word.\n
 4. Read the completed story aloud for hilarious results!''')
print()
# Out:
# RULES:
#
#  1.	Ask your friend to input the words.
#
#  2. Ask for a word that matches each part of speech (e.g., "Give me an adjective for blank 1")
#
#  3. Input the word.
#
#  4. Read the completed story aloud for hilarious results!

# %% [markdown]
# #### Asking the User to Input words (Including the part of speech, the word should be)

# %%
adj1= input('Please Enter an Adjective (silly/weird): ')

adj2= input('Please Enter an Adjective (ridiculous): ')

num1= input ('Please Enter a Number (between 1-12): ')

nplace = input('Please Enter a Proper Noun (made-up place name): ')

noun1 = input('Please Enter a Noun (imagination, dreams, etc.): ')

nperson =input ('Please Enter a Noun (person/creature): ')

print()
print()
# Out:
# Please Enter an Adjective (silly/weird):  Rubber
# Please Enter an Adjective (ridiculous):  Inflatable
# Please Enter a Number (between 1-12):  3
# Please Enter a Proper Noun (made-up place name):  Spaghetti Land
# Please Enter a Noun (imagination, dreams, etc.):  Fever dream
# Please Enter a Noun (person/creature):  Minotaur

# %% [markdown]
# #### Using a f string to enter user input values into our Madlib.

# %%
madlib = (f'''Last summer, I decided to take the most {adj1} vacation of my life.
I packed my suitcase with {adj2} items and headed to the airport at {num1} AM looking absolutely ridiculous.\n

At check-in, the agent took one look at me and asked, 
"Where exactly are you going?" I replied confidently, "I'm heading to {nplace}!" She stared at me blankly and said,
"That's not a real place, is it?" I assured her it definitely was, at least in my {noun1}.\n

On the plane, I sat next to a {nperson} who immediately fell asleep and started snoring so loudly that the flight attendant asked if we'd brought livestock onboard. 
I considered asking for a refund right then and there.
 ''')

# %% [markdown]
# #### Printing out the Hilarious output.

# %%
print(madlib)
# Out:
# Last summer, I decided to take the most Rubber vacation of my life.
# I packed my suitcase with Inflatable items and headed to the airport at 3 AM looking absolutely ridiculous.
#
#
# At check-in, the agent took one look at me and asked,
# "Where exactly are you going?" I replied confidently, "I'm heading to Spaghetti Land !" She stared at me blankly and said,
# "That's not a real place, is it?" I assured her it definitely was, at least in my Fever dream .
#
#
# On the plane, I sat next to a Minotaur  who immediately fell asleep and started snoring so loudly that the flight attendant asked if we'd brought livestock onboard.
# I considered asking for a refund right then and there.
